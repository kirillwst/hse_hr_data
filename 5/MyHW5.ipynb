# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('HRDataset_v14.csv')

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
shapiro_test = stats.shapiro(df['EmpSatisfaction'])

# %%
shapiro_test
# Out:
# ShapiroResult(statistic=0.8421188592910767, pvalue=3.660982938895983e-17)

# %%
plt.hist(df['EmpSatisfaction'], color = 'blue', edgecolor = 'black') 
plt.show()

# %%
# тут мы очевидно видем, что велеичны распределены ненормально  
# 0-вая гипотеза Шапиро-Уилки отвергается
